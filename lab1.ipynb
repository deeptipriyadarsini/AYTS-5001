# %%
print("Hello world")
# Out:
# Hello world

# %%
name="deepti"
age=46
height=1.6256
student_status=True
print(type(name))
print(type(age))
print(type(height))
print(type(student_status))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
user_name=input("enter your name")
user_age=input("enter your age")
print(f"hi {user_name},you are {user_age}years old")
# Out:
# enter your name Jason
# enter your age 18
# hi Jason,you are 18years old

# %%
h=int(input("enter height"))
w=int(input("enter width"))
area=h*w
perimeter=2*(h+w)
print(f"The area is {area}")
print(f"The perimeter is{perimeter}")
# Out:
# enter height 5
# enter width 8
# The area is 40
# The perimeter is26

# %%
git remote add origin https://github.com/deeptipriyadarsini/AYTS-5001.git
git branch -M main
git push -u origin main
# Out:
#   Cell In[12], line 1
#     git remote add origin https://github.com/deeptipriyadarsini/AYTS-5001.git
#                                                                          ^
# SyntaxError: invalid decimal literal
